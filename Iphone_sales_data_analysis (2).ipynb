# %%
import pandas as pd

# %%
df=pd.read_csv('apple.csv')
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.tail()
# Out:
#                        Product Name  \
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 57  39900                   24              95909               8161
# 58  54900                   14              43470               3331
# 59  54900                   14              43470               3331
# ...

# %% [markdown]
# # Top 5 star rating apple phones

# %%
df_sorted_highest=df.sort_values('Star Rating',ascending=False).head(10)
df_sorted_highest
# Out:
#                                         Product Name  \
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 0                  APPLE iPhone 8 Plus (Gold, 64 GB)
# 29                   APPLE iPhone 12 (White, 128 GB)
# 32        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 35                   APPLE iPhone 12 (Black, 128 GB)
# 36                    APPLE iPhone 12 (Blue, 128 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 15  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# ...

# %% [markdown]
# # Lowest 5 star rating apple phones

# %%
df_sorted_lowest=df.sort_values('Star Rating').head(10)

# %% [markdown]
# # Apple phone has highest number of reviews

# %%
df_highest_reviews=df.sort_values('Number Of Reviews',ascending=False)
df_highest_reviews.head(10)
# Out:
#                                          Product Name  \
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 53                    APPLE iPhone SE (Black, 128 GB)
# 55                      APPLE iPhone SE (Red, 128 GB)
# 57                     APPLE iPhone SE (Black, 64 GB)
# 52                     APPLE iPhone SE (White, 64 GB)
# 54                    APPLE iPhone SE (White, 128 GB)
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
#
#                                           Product URL  Brand  Sale Price  \
# 23  https://www.flipkart.com/apple-iphone-se-white...  Apple       44999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# 55  https://www.flipkart.com/apple-iphone-se-red-1...  Apple       34999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# ...

# %% [markdown]
# # Apple phone has lowest number of reviews

# %%
df_lowest_reviews=df.sort_values('Number Of Reviews').head(10)
df_lowest_reviews
# Out:
#                                       Product Name  \
# 30          APPLE iPhone 12 Pro (Graphite, 128 GB)
# 27          APPLE iPhone 12 Pro (Graphite, 256 GB)
# 24            APPLE iPhone 12 Pro (Silver, 512 GB)
# 46      APPLE iPhone 12 Pro (Pacific Blue, 128 GB)
# 41      APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 25  APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 37        APPLE iPhone 12 Pro Max (Silver, 128 GB)
# 32      APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 39          APPLE iPhone 12 Pro Max (Gold, 128 GB)
# 31      APPLE iPhone 12 Pro Max (Graphite, 256 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 30  https://www.flipkart.com/apple-iphone-12-pro-g...  Apple      110900
# 27  https://www.flipkart.com/apple-iphone-12-pro-g...  Apple      120900
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 46  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      110900
# ...

# %% [markdown]
# # Relationship between sale price and number of ratings

# %% [markdown]
# # Relationship between sale price and number of reviews

# %%
correlation = df['Sale Price'].corr(df['Number Of Reviews'])
print(correlation)
# Out:
# -0.6960291835220087

# %% [markdown]
# # Relationship between discount percentage and number of ratings

# %%
correlation = df['Discount Percentage'].corr(df['Number Of Ratings'])
print(correlation)
# Out:
# 0.6848270553540624

# %% [markdown]
# # Relationship between discount percentage and number of ratings

# %%
correlation = df['Discount Percentage'].corr(df['Number Of Reviews'])
print(correlation)
# Out:
# 0.6858769720978277

# %% [markdown]
# # Most expensive and least expensive apple phone

# %% [markdown]
# # New Section

# %%
df_sorted=df.sort_values('Sale Price',ascending=False)
most_expensive_phone=df_sorted.iloc[0]
most_expensive_phone
# Out:
# Product Name                  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# Product URL            https://www.flipkart.com/apple-iphone-12-pro-p...
# Brand                                                              Apple
# Sale Price                                                        140900
# Mrp                                                               149900
# Discount Percentage                                                    6
# Number Of Ratings                                                    545
# Number Of Reviews                                                     42
# Upc                                                     MOBFWBYZTHSXKMGW
# Star Rating                                                          4.5
# Ram                                                                 4 GB
# Name: 41, dtype: object

# %%
product_rating = df['Product Name']
product_rating
# Out:
# 0            APPLE iPhone 8 Plus (Gold, 64 GB)
# 1     APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2         APPLE iPhone 8 Plus (Silver, 256 GB)
# 3              APPLE iPhone 8 (Silver, 256 GB)
# 4                APPLE iPhone 8 (Gold, 256 GB)
#                         ...
# 57              APPLE iPhone SE (Black, 64 GB)
# 58             APPLE iPhone 11 (Purple, 64 GB)
# 59              APPLE iPhone 11 (White, 64 GB)
# 60              APPLE iPhone 11 (Black, 64 GB)
# 61                APPLE iPhone 11 (Red, 64 GB)
# Name: Product Name, Length: 62, dtype: object

# %%
import plotly.express as px
label = df_sorted_highest['Product Name']
counts = df_sorted_highest['Number Of Ratings']
fig = px.bar(x=label, y=counts, title='Number Of Ratings')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
label = df_sorted_highest['Product Name']
counts = df_sorted_highest['Number Of Reviews']
fig = px.bar(x=label, y=counts, title='Number Of Reviews')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Iphone Sale Price and Rating Relationship
fg = px.scatter(data_frame=df, x='Number Of Ratings', y='Sale Price', size='Discount Percentage', trendline='ols',title='Sale Price VS Rating')
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Iphone Discount Percentage and Rating Relationship
fg = px.scatter(data_frame=df, x='Number Of Ratings', y='Discount Percentage', size='Sale Price', trendline='ols',title='Discount Percentage VS Rating')
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Most Expensive and Least Expensive Iphone
product_sale_price = df[['Product Name','Sale Price']]
product_sale_price
# Out:
#                                 Product Name  Sale Price
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)       49900
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)       84900
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)       84900
# 3            APPLE iPhone 8 (Silver, 256 GB)       77000
# 4              APPLE iPhone 8 (Gold, 256 GB)       77000
# ..                                       ...         ...
# 57            APPLE iPhone SE (Black, 64 GB)       29999
# 58           APPLE iPhone 11 (Purple, 64 GB)       46999
# 59            APPLE iPhone 11 (White, 64 GB)       46999
# 60            APPLE iPhone 11 (Black, 64 GB)       46999
# 61              APPLE iPhone 11 (Red, 64 GB)       46999
#
# [62 rows x 2 columns]

# %%
sale_price = product_sale_price['Sale Price']
sale_price
# Out:
# 0     49900
# 1     84900
# 2     84900
# 3     77000
# 4     77000
#       ...
# 57    29999
# 58    46999
# 59    46999
# 60    46999
# 61    46999
# Name: Sale Price, Length: 62, dtype: int64

# %%
least_expensive = df.loc[df['Sale Price'].idxmin()]
most_expensive = df.loc[df['Sale Price'].idxmax()]

# %%
least_expensive
# Out:
# Product Name                              APPLE iPhone SE (White, 64 GB)
# Product URL            https://www.flipkart.com/apple-iphone-se-white...
# Brand                                                              Apple
# Sale Price                                                         29999
# Mrp                                                                39900
# Discount Percentage                                                   24
# Number Of Ratings                                                  95807
# Number Of Reviews                                                   8154
# Upc                                                     MOBFWQ6BGWDVGF3E
# Star Rating                                                          4.5
# Ram                                                                 2 GB
# Name: 52, dtype: object

# %%
most_expensive
# Out:
# Product Name                        APPLE iPhone 12 Pro (Silver, 512 GB)
# Product URL            https://www.flipkart.com/apple-iphone-12-pro-s...
# Brand                                                              Apple
# Sale Price                                                        140900
# Mrp                                                               149900
# Discount Percentage                                                    6
# Number Of Ratings                                                    542
# Number Of Reviews                                                     42
# Upc                                                     MOBFWBYZ5UY6ZBVA
# Star Rating                                                          4.5
# Ram                                                                 4 GB
# Name: 24, dtype: object
